# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
data.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
#
# [3 rows x 23 columns]

# %%
len(data)
# Out:
# 126314

# %%
data.shape
# Out:
# (126314, 23)

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
data.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 22.2+ MB

# %%
data.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# min      1091.64    1085.77      10.15       0.00    1091.64    1085.77
# 25%      1417.24    1416.99      34.10      93.00    1417.24    1416.99
# 50%      1500.95    1500.95      42.11     103.00    1500.95    1500.95
# 75%      1576.06    1576.29      49.64     112.00    1576.06    1576.29
# max      1853.10    1853.10      71.11     186.00    1853.10    1853.10
#
#         forecast
# count  126314.00
# mean        0.50
# std         0.22
# min         0.02
# 25%         0.33
# 50%         0.50
# 75%         0.67
# max         0.98

# %%
data["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
data["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# Steamrollers     168
# Packers           72
# Redskins          65
# Rebels            63
# Waterloo          62
# Denver            62
# Falcons           60
# Jets              60
# Ironmen           60
# Huskies           60
# Name: fran_id, dtype: int64

# %%
data.loc[data["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
data.loc[data["team_id"] == "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
data.loc[data["team_id"] == "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
data.loc[data["team_id"] == "LAL", "date_game"].min()
# Out:
# '1/1/1961'

# %%
data.loc[data["team_id"] == "LAL", "date_game"].max()
# Out:
# '6/9/2009'

# %%
data.loc[data["team_id"] == "MNL", "date_game"].agg(("min", "max"))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
data.loc[data["team_id"] == "LAL", "pts"].sum()
# Out:
# 549215

# %%
data["pts"]
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %% [markdown]
# ## Series

# %%
revanues = pd.Series((100,323,700))

# %%
revanues.values
# Out:
# array([100, 323, 700], dtype=int64)

# %%
revanues[1]
# Out:
# 323

# %%
city_revenues = pd.Series(
    [3000, 5000,2100],
    index=["Amsterdam", "Toronto", "Tokyo"]
)

# %%
city_revenues
# Out:
# Amsterdam    3000
# Toronto      5000
# Tokyo        2100
# dtype: int64

# %%
city_employee_count = pd.Series(
    {
        "Amsterdam" : 5,
        "Tokyo" : 9
    }
)

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        9
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count" : city_employee_count
})

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[3000.,    5.],
#        [2100.,    9.],
#        [5000.,   nan]])

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
"revenue" in city_data
# Out:
# True

# %%
data.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"points" in data.columns
# Out:
# False

# %%
"pts" in data.columns
# Out:
# True

# %% [markdown]
# ## Slicing

# %%
city_revenues
# Out:
# Amsterdam    3000
# Toronto      5000
# Tokyo        2100
# dtype: int64

# %%
city_revenues["Amsterdam"]
# Out:
# 3000

# %%
city_revenues[0:2]
# Out:
# Amsterdam    3000
# Toronto      5000
# dtype: int64

# %%
city_revenues["Amsterdam":"Toronto"]
# Out:
# Amsterdam    3000
# Toronto      5000
# dtype: int64

# %%
city_revenues[-1]
# Out:
# 2100

# %%
city_revenues[-1::-1]
# Out:
# Tokyo        2100
# Toronto      5000
# Amsterdam    3000
# dtype: int64

# %%
colors = pd.Series(
    ["red","purple","blue","green","yellow"],
    index= [1,2,3,5,10] 
)

# %%
colors
# Out:
# 1        red
# 2     purple
# 3       blue
# 5      green
# 10    yellow
# dtype: object

# %%
colors[1]
# Out:
# 'red'

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
colors.loc[1]
# Out:
# 'red'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.iloc[-1]
# Out:
# 'yellow'

# %%
data.loc[0,"game_id"]
# Out:
# '194611010TRH'

# %%
data.iloc[0,1]
# Out:
# '194611010TRH'

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
city_data["employee_count"]
# Out:
# Amsterdam    5.0
# Tokyo        9.0
# Toronto      NaN
# Name: employee_count, dtype: float64

# %%
city_data.revenue
# Out:
# Amsterdam    3000
# Tokyo        2100
# Toronto      5000
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame(
    {
        "name": ["ball", "Rubik's cube"],
        "shape": ["sphare", "cube"]
    }
)

# %%
toys["shape"]
# Out:
# 0    sphare
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
city_data.loc["Amsterdam":"Toronto"]
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
city_data.iloc[1]
# Out:
# revenue           2100.0
# employee_count       9.0
# Name: Tokyo, dtype: float64

# %%
city_data.loc["Amsterdam":"Tokyo", "revenue":"employee_count"]
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0

# %% [markdown]
# ## Query data Frame

# %%
data
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [126314 rows x 23 columns]

# %%
curent_decade= data[data["year_id"] > 2010]

# %%
curent_decade.shape
# Out:
# (12658, 23)

# %%
notes_available = data[data['notes'].notnull()]

# %%
notes_available
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 930             28            0     WSC      Capitols   71  1469.35  1454.90
# 931             31            0     BLB     Baltimore   95  1434.05  1448.50
# 1084            49            1     WSC      Capitols   70  1465.90  1461.20
# 1085            49            1     CHS         Stags   74  1440.72  1445.42
# 1088            49            1     BLB     Baltimore   75  1477.26  1484.31
# ...            ...          ...     ...           ...  ...      ...      ...
# 122207          39            0     ATL         Hawks  110  1505.05  1487.59
# 123916           8            0     HOU       Rockets  113  1635.77  1642.45
# 123917           7            0     MIN  Timberwolves  101  1502.92  1496.24
# 124862          40            0     MIL         Bucks   95  1499.90  1505.86
# 124863          41            0     NYK        Knicks   79  1304.46  1298.50
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 930         47.07    BLB     Baltimore       95    1434.05    1448.50
# 931         46.41    WSC      Capitols       71    1469.35    1454.90
# 1084        47.71    CHS         Stags       74    1440.72    1445.42
# 1085        46.09    WSC      Capitols       70    1465.90    1461.20
# 1088        50.04    CHS         Stags       72    1445.42    1438.36
# ...           ...    ...           ...      ...        ...        ...
# 122207      39.24    BRK          Nets      127    1454.65    1472.11
# 123916      54.89    MIN  Timberwolves      101    1502.92    1496.24
# 123917      40.13    HOU       Rockets      113    1635.77    1642.45
# 124862      41.14    NYK        Knicks       79    1304.46    1298.50
# 124863      21.19    MIL         Bucks       95    1499.90    1505.86
#
#        game_location game_result  forecast  \
# 930                A           L      0.41
# 931                H           W      0.59
# 1084               A           L      0.39
# 1085               H           W      0.61
# 1088               A           W      0.40
# ...              ...         ...       ...
# 122207             N           L      0.57
# 123916             N           W      0.68
# 123917             N           L      0.32
# 124862             N           W      0.75
# 124863             N           L      0.25
#
#                                             notes
# 930          at Baltimore's Fifth Regiment Armory
# 931          at Baltimore's Fifth Regiment Armory
# 1084                                   Tiebreaker
# 1085                                   Tiebreaker
# 1088                                   Tiebreaker
# ...                                           ...
# 122207                         at London, England
# 123916  at Mexico City Arena, Mexico City, Mexico
# 123917  at Mexico City Arena, Mexico City, Mexico
# 124862                 at The O2, London, England
# 124863                 at The O2, London, England
#
# [5424 rows x 23 columns]

# %%
notes_available.shape
# Out:
# (5424, 23)

# %%
data[data['notes'].isna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [120890 rows x 23 columns]

# %%
ers = data(data["fran_id"].str.endswith["ers"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 77' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y136sZmlsZQ%3D%3D?line=0'>1</a> ers = data(data["fran_id"].str.endswith["ers"])
#
# TypeError: 'method' object is not subscriptable

# %%
ers.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 78' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y141sZmlsZQ%3D%3D?line=0'>1</a> ers.shape
#
# NameError: name 'ers' is not defined

# %%
ers["fran_id"]

# %%
data[
    (data["_iscopy"]==0) &
    (data["pts"] > 100) &
    (data["opp_pts"]> 100) &
    (data["team_id"] == "LAL")
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9744         4873  196010240LAL   NBA        0     1961  10/24/1960
# 9747         4874  196010250LAL   NBA        0     1961  10/25/1960
# 9778         4890  196011050LAL   NBA        0     1961   11/5/1960
# 9782         4892  196011060LAL   NBA        0     1961   11/6/1960
# 9786         4894  196011090LAL   NBA        0     1961   11/9/1960
# ...           ...           ...   ...      ...      ...         ...
# 125073      62537  201501290LAL   NBA        0     2015   1/29/2015
# 125301      62651  201502200LAL   NBA        0     2015   2/20/2015
# 125335      62668  201502220LAL   NBA        0     2015   2/22/2015
# 125450      62726  201503010LAL   NBA        0     2015    3/1/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 9744             3            0     LAL  Lakers  101  1450.41  1435.35
# 9747             4            0     LAL  Lakers  120  1435.35  1438.79
# 9778             8            0     LAL  Lakers  112  1441.12  1446.19
# 9782             9            0     LAL  Lakers  119  1446.19  1454.00
# 9786            10            0     LAL  Lakers  118  1454.00  1448.49
# ...            ...          ...     ...     ...  ...      ...      ...
# 125073          47            0     LAL  Lakers  123  1365.22  1374.75
# 125301          54            0     LAL  Lakers  105  1338.76  1329.16
# 125335          55            0     LAL  Lakers  118  1329.16  1336.94
# 125450          58            0     LAL  Lakers  101  1360.30  1356.05
# 126086          80            0     LAL  Lakers  106  1312.95  1305.92
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 9744        33.24    NYK     Knicks      111    1435.75    1450.82
# 9747        33.59    NYK     Knicks      118    1450.82    1447.37
# 9778        34.34    SYR     Sixers      110    1554.17    1549.10
# 9782        35.14    SYR     Sixers      113    1549.10    1541.28
# 9786        34.58    PHW   Warriors      125    1657.96    1663.47
# ...           ...    ...        ...      ...        ...        ...
# 125073      27.86    CHI      Bulls      118    1556.17    1546.64
# 125301      23.75    BRK       Nets      114    1442.50    1452.10
# 125335      24.42    BOS    Celtics      111    1408.33    1400.55
# 125450      26.13    OKC    Thunder      108    1620.30    1624.55
# 126086      21.79    DAL  Mavericks      120    1556.22    1563.25
#
#        game_location game_result  forecast                notes
# 9744               H           L      0.66                  NaN
# 9747               H           W      0.62                  NaN
# 9778               H           W      0.48                  NaN
# 9782               H           W      0.50  at San Francisco CA
# 9786               H           L      0.35      at St. Louis MO
# ...              ...         ...       ...                  ...
# 125073             H           W      0.37                  NaN
# 125301             H           L      0.49                  NaN
# 125335             H           W      0.53                  NaN
# 125450             H           L      0.28                  NaN
# 126086             H           L      0.30                  NaN
#
# [1330 rows x 23 columns]

# %%
data[
    (data["_iscopy"]==0) &
    (data["team_id"].str.startswith("LA")) &
    (data["year_id"] == 1992) &
    (data["notes"].notna())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts    elo_i   elo_n  win_equiv opp_id  \
# 68901            1     LAC  Clippers  115  1546.90  1556.0      47.89    UTA
# 68903            1     LAL    Lakers   76  1489.65  1474.4      39.40    POR
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 68901          Jazz      107    1647.51    1638.41             H           W
# 68903  Trailblazers      102    1655.12    1670.37             H           L
#
#        forecast                                       notes
# 68901      0.50  at Anaheim, CA (Anaheim Convention Center)
# 68903      0.41                            at Las Vegas, NV

# %% [markdown]
# ## Grouping

# %%
city_revenues.sum()
# Out:
# 10100

# %%
city_revenues.max()
# Out:
# 5000

# %%
city_revenues.mean()
# Out:
# 3366.6666666666665

# %%
city_revenues.std()
# Out:
# 1484.362938547488

# %%
data[data['year_id'] > 2010].groupby(by="fran_id") ["pts"].sum()
# Out:
# fran_id
# Bucks           38901
# Bulls           42723
# Cavaliers       40371
# Celtics         41512
# Clippers        44908
# Grizzlies       43130
# Hawks           43167
# Heat            47815
# Hornets         37081
# Jazz            38705
# Kings           39439
# Knicks          40847
# Lakers          42040
# Magic           38780
# Mavericks       43754
# Nets            40347
# Nuggets         43048
# Pacers          43155
# Pelicans        38677
# Pistons         38089
# Raptors         39971
# Rockets         44309
# Sixers          39183
# Spurs           48162
# Suns            39934
# Thunder         48093
# Timberwolves    39387
# Trailblazers    41633
# Warriors        44937
# Wizards         40140
# Name: pts, dtype: int64

# %%
data[
    (data["fran_id"] == "Warriors")
]

# %%
nba = data.copy()

# %%
nba.shape
# Out:
# (126314, 23)

# %%
data.shape
# Out:
# (126314, 23)

# %%
nba["pts_diff"] = nba["pts"] = nba["opp_pts"]

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes  pts_diff
# 0                  H           L      0.64   NaN        68
# 1                  A           W      0.36   NaN        66
# 2                  H           W      0.63   NaN        47
# 3                  A           L      0.37   NaN        63
# 4                  H           L      0.64   NaN        50
# ...              ...         ...       ...   ...       ...
# 126309             H           L      0.55   NaN       103
# 126310             H           W      0.77   NaN        91
# 126311             A           L      0.23   NaN       104
# 126312             H           L      0.48   NaN       105
# 126313             A           W      0.52   NaN        97
#
# [126314 rows x 24 columns]

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba["pts_diff"].max()
# Out:
# 186

# %%
nba["pts_diff"].min()
# Out:
# 0

# %%
import numpy as np

# %%
nba["pts_diff_abs"] = np.abs[nba["pts_diff"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 98' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y201sZmlsZQ%3D%3D?line=0'>1</a> nba["pts_diff_abs"] = np.abs[nba["pts_diff"]]
#
# TypeError: 'numpy.ufunc' object is not subscriptable

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes  pts_diff
# 0                  H           L      0.64   NaN        68
# 1                  A           W      0.36   NaN        66
# 2                  H           W      0.63   NaN        47
# 3                  A           L      0.37   NaN        63
# 4                  H           L      0.64   NaN        50
# ...              ...         ...       ...   ...       ...
# 126309             H           L      0.55   NaN       103
# 126310             H           W      0.77   NaN        91
# 126311             A           L      0.23   NaN       104
# 126312             H           L      0.48   NaN       105
# 126313             A           W      0.52   NaN        97
#
# [126314 rows x 24 columns]

# %%
nba.rename(
    columns={"game_result" : "result", "game_location" : "location"}
    
)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n location  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72        H
# 1           41.71    TRH    Huskies       66    1300.00    1293.28        A
# 2           42.01    NYK     Knicks       47    1306.72    1297.07        H
# 3           40.69    CHS      Stags       63    1300.00    1309.65        A
# 4           38.86    WSC   Capitols       50    1300.00    1320.38        H
# ...           ...    ...        ...      ...        ...        ...      ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98        H
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74        H
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63        A
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29        H
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09        A
#
#        result  forecast notes  pts_diff
# 0           L      0.64   NaN        68
# 1           W      0.36   NaN        66
# 2           W      0.63   NaN        47
# 3           L      0.37   NaN        63
# 4           L      0.64   NaN        50
# ...       ...       ...   ...       ...
# 126309      L      0.55   NaN       103
# 126310      W      0.77   NaN        91
# 126311      L      0.23   NaN       104
# 126312      L      0.48   NaN       105
# 126313      W      0.52   NaN        97
#
# [126314 rows x 24 columns]

# %%
elo_co = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]

# %%
nba.drop(elo_co, axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   68      40.29    NYK
# 1                1            0     NYK     Knicks   66      41.71    TRH
# 2                1            0     CHS      Stags   47      42.01    NYK
# 3                2            0     NYK     Knicks   63      40.69    CHS
# 4                1            0     DTF    Falcons   50      38.86    WSC
# ...            ...          ...     ...        ...  ...        ...    ...
# 126309         100            1     CLE  Cavaliers  103      60.31    GSW
# 126310         102            1     GSW   Warriors   91      68.01    CLE
# 126311         101            1     CLE  Cavaliers  104      60.01    GSW
# 126312         102            1     CLE  Cavaliers  105      59.29    GSW
# 126313         103            1     GSW   Warriors   97      68.52    CLE
#
#          opp_fran  opp_pts game_location game_result  forecast notes  pts_diff
# 0          Knicks       68             H           L      0.64   NaN        68
# 1         Huskies       66             A           W      0.36   NaN        66
# 2          Knicks       47             H           W      0.63   NaN        47
# 3           Stags       63             A           L      0.37   NaN        63
# 4        Capitols       50             H           L      0.64   NaN        50
# ...           ...      ...           ...         ...       ...   ...       ...
# 126309   Warriors      103             H           L      0.55   NaN       103
# 126310  Cavaliers       91             H           W      0.77   NaN        91
# 126311   Warriors      104             A           L      0.23   NaN       104
# 126312   Warriors      105             H           L      0.48   NaN       105
# 126313  Cavaliers       97             A           W      0.52   NaN        97
#
# [126314 rows x 20 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
#  23  pts_diff       126314 non-null  int64
# dtypes: float64(6), int64(8), object(10)
# memory usage: 23.1+ MB

# %%
nba['location'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 104' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y211sZmlsZQ%3D%3D?line=0'>1</a> nba['location'].value_counts()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'location'

# %%
nba['location']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 105' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y212sZmlsZQ%3D%3D?line=0'>1</a> nba['location']
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'location'

# %%
pd.Categorical(nba['location'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 106' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y213sZmlsZQ%3D%3D?line=0'>1</a> pd.Categorical(nba['location'])
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'location'

# %%
nba['location'].dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 107' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y214sZmlsZQ%3D%3D?line=0'>1</a> data=['location'].dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
nba["pts_diff"].astype(np.float)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17780\3860855832.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   nba["pts_diff"].astype(np.float)
# 0          68.0
# 1          66.0
# 2          47.0
# 3          63.0
# 4          50.0
#           ...
# 126309    103.0
# 126310     91.0
# 126311    104.0
# 126312    105.0
# 126313     97.0
# Name: pts_diff, Length: 126314, dtype: float64

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
#  23  pts_diff       126314 non-null  int64
# dtypes: float64(6), int64(8), object(10)
# memory usage: 23.1+ MB

# %%
nba_no_miss_col = nba.dropna(axis=1)

# %%
nba_no_miss_col
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast  pts_diff
# 0                  H           L      0.64        68
# 1                  A           W      0.36        66
# 2                  H           W      0.63        47
# 3                  A           L      0.37        63
# 4                  H           L      0.64        50
# ...              ...         ...       ...       ...
# 126309             H           L      0.55       103
# 126310             H           W      0.77        91
# 126311             A           L      0.23       104
# 126312             H           L      0.48       105
# 126313             A           W      0.52        97
#
# [126314 rows x 23 columns]

# %%
nba.info
# Out:
# <bound method DataFrame.info of         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes  pts_diff
# 0                  H           L      0.64   NaN        68
# 1                  A           W      0.36   NaN        66
# 2                  H           W      0.63   NaN        47
# 3                  A           L      0.37   NaN        63
# 4                  H           L      0.64   NaN        50
# ...              ...         ...       ...   ...       ...
# 126309             H           L      0.55   NaN       103
# 126310             H           W      0.77   NaN        91
# 126311             A           L      0.23   NaN       104
# 126312             H           L      0.48   NaN       105
# 126313             A           W      0.52   NaN        97
#
# [126314 rows x 24 columns]>

# %%
nba_copy = nba.copy()

# %%
nba_copy["notes"].fillna(
    value="No note",
    inplace = True
)

# %%
nba_copy["notes"].describe()
# Out:
# count      126314
# unique        232
# top       No note
# freq       120890
# Name: notes, dtype: object

# %%
nba[nba["pts"] ==0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26685      13343  197210260VIR   ABA        0     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 26685           8            0     VIR  Squires    0  1484.19  1487.08
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 26685      43.51    DNR  Nuggets        0    1460.34    1457.45             H
#
#       game_result  forecast                           notes  pts_diff
# 26685           W      0.67  at Richmond VA; forfeit to VIR         0

# %%
nba.drop(26684, axis=0)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes  pts_diff
# 0                  H           L      0.64   NaN        68
# 1                  A           W      0.36   NaN        66
# 2                  H           W      0.63   NaN        47
# 3                  A           L      0.37   NaN        63
# 4                  H           L      0.64   NaN        50
# ...              ...         ...       ...   ...       ...
# 126309             H           L      0.55   NaN       103
# 126310             H           W      0.77   NaN        91
# 126311             A           L      0.23   NaN       104
# 126312             H           L      0.48   NaN       105
# 126313             A           W      0.52   NaN        97
#
# [126313 rows x 24 columns]

# %%
nba[(nba["pts"] > nba["opp_pts"])]["game_result"].value_counts()
# Out:
# Series([], Name: game_result, dtype: int64)

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
another_city_data = pd.DataFrame(
    {
    "revenue": [4500,8000],
    "employee_count": [2,2]}
    ,index= ["New York" , "Barcelona"]
)

# %%
another_city_data
# Out:
#            revenue  employee_count
# New York      4500               2
# Barcelona     8000               2

# %%
all_city_data = pd.concat([city_data,another_city_data])

# %%
city_countries = pd.DataFrame(
    {"country": ["Holland", "Japan", "Holland", "canada", "spain"]
    ,"capital": [1,1,0,0,0]}
    ,index=["Amsterdam","Tokyo","Roterdam","Toronto","Barcelona"])

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Roterdam   Holland        0
# Toronto     canada        0
# Barcelona    spain        0

# %%
countries = pd.DataFrame({
    "population": [17,127,37],
    "Continent": ["Europa", "ASIA", "North AMerica"]
})

# %%
countries
# Out:
#    population      Continent
# 0          17         Europa
# 1         127           ASIA
# 2          37  North AMerica

# %%
pd.merge(left=cities,right=countries, left_an= "country", right_index=True, how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\semester 6\satu\pertemuan 5.ipynb Cell 128' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/semester%206/satu/pertemuan%205.ipynb#Y244sZmlsZQ%3D%3D?line=0'>1</a> pd.merge(left=cities,right=countries, left_an= "country", right_index=True, how="left")
#
# NameError: name 'cities' is not defined

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   68  1300.00  1293.28
# 1                1            0     NYK     Knicks   66  1300.00  1306.72
# 2                1            0     CHS      Stags   47  1300.00  1309.65
# 3                2            0     NYK     Knicks   63  1306.72  1297.07
# 4                1            0     DTF    Falcons   50  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers  103  1723.41  1704.39
# 126310         102            1     GSW   Warriors   91  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers  104  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers  105  1700.74  1692.09
# 126313         103            1     GSW   Warriors   97  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes  pts_diff
# 0                  H           L      0.64   NaN        68
# 1                  A           W      0.36   NaN        66
# 2                  H           W      0.63   NaN        47
# 3                  A           L      0.37   NaN        63
# 4                  H           L      0.64   NaN        50
# ...              ...         ...       ...   ...       ...
# 126309             H           L      0.55   NaN       103
# 126310             H           W      0.77   NaN        91
# 126311             A           L      0.23   NaN       104
# 126312             H           L      0.48   NaN       105
# 126313             A           W      0.52   NaN        97
#
# [126314 rows x 24 columns]

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum()
# Out:
# year_id
# 1947    4218
# 1948    3665
# 1949    5163
# 1950    5772
# 1951    6809
#         ...
# 2011    9067
# 2012    6731
# 2013    8880
# 2014    8149
# 2015    8299
# Name: pts, Length: 69, dtype: int64
